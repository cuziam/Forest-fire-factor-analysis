# %% [markdown]
# <a href="https://colab.research.google.com/github/cuziam/Forest-fire-factor-analysis/blob/main/fire_over_5ha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 한글이 안 깨지려면 1,2번 과정을 반드시 먼저 실행할 것.
#
# *  mean-log 값을 얻으려면 3,4번 과정 순서대로 실행.
# *  random-forest로 중요도를 얻으려면 5번 과정 부터 실행.

# %% [markdown]
# 1. 그래프에 한글 폰트를 적용하기 위해, '나눔' 폰트 패밀리 설치

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# 2. 폰트 패밀리가 잘 설치되었는지 확인

# %%
import matplotlib.font_manager as fm

font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['DejaVu Serif',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'cmss10',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXSizeFiveSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'cmmi10',
#  'cmtt10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmr10',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumGothicCoding',
#  'NanumBarunGothic',
#  'Liberation Serif',
#  'NanumMyeongjo',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'NanumGothic',
#  'Liberation Sans Narrow',
#  'Liberation Sans Narrow',
#  'NanumGothicCoding',
#  'NanumSquareRound',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Humor Sans',
#  'NanumGothic',
#  'Liberation Mono',
#  'Liberation Serif',
#  'Liberation Sans',
#  'Liberation Mono',
#  'Liberation Mono',
#  'NanumBarunGothic',
#  'NanumSquare',
#  'NanumSquareRound',
#  'Liberation Sans Narrow',
#  'Liberation Sans']

# %% [markdown]
# 3. csv파일을 읽어온 후, 워드1~워드5까지의 요소 중 mean log value값 top10만 뽑아서 그래프 그리기

# %%
# Import required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc("font", family = "NanumGothic")
sns.set(font="NanumGothic",
rc={"axes.unicode_minus":False}, style='white')

# Read the CSV file (replace 'your_file.csv' with the actual file path)
df_csv = pd.read_csv('./rawData/fire-over-5ha.csv')

# Skip irrelevant rows and columns to get to the actual data
df_csv_cleaned = df_csv.iloc[2:]
df_csv_cleaned.columns = df_csv.iloc[1]

# Rename the columns for easier access
df_csv_cleaned.rename(columns={
    'Unnamed: 23': '워드1',
    'Unnamed: 24': '워드2',
    'Unnamed: 25': '워드3',
    'Unnamed: 26': '워드4',
    'Unnamed: 27': '워드5',
}, inplace=True)

# Drop any rows where 'log' or 'Word' columns are NaN
df_csv_cleaned.dropna(subset=['워드1', '워드2', '워드3', '워드4', '워드5', 'log'], inplace=True)

# Convert 'Word' columns to string type and 'log' column to float type
for col in ['워드1', '워드2', '워드3', '워드4', '워드5']:
    df_csv_cleaned[col] = df_csv_cleaned[col].astype(str)
df_csv_cleaned['log'] = df_csv_cleaned['log'].astype(float)

# Create a DataFrame for consolidated mean log values across all 'Word' columns
consolidated_mean_log_values_csv = pd.concat([df_csv_cleaned[col] for col in ['워드1', '워드2', '워드3', '워드4', '워드5']],
                                             keys=['워드1', '워드2', '워드3', '워드4', '워드5']).reset_index()
consolidated_mean_log_values_csv.columns = ['Word_Column', 'Index', 'Category']
consolidated_mean_log_values_csv['log'] = df_csv_cleaned['log'].repeat(5).reset_index(drop=True)

# Calculate mean log value for each category across all 'Word' columns
group_means_consolidated_csv = consolidated_mean_log_values_csv.groupby('Category')['log'].mean().reset_index()
group_means_consolidated_csv.columns = ['Category', 'Consolidated_Mean_Log_Value']

# Sort by 'Consolidated_Mean_Log_Value' and take the top 10 categories
top10_overall_consolidated_csv = group_means_consolidated_csv.sort_values('Consolidated_Mean_Log_Value', ascending=False).head(10)

# Plotting the data
plt.figure(figsize=(15, 8))
sns.barplot(data=top10_overall_consolidated_csv, x='Category', y='Consolidated_Mean_Log_Value')
plt.title('Top 10 Categories by Consolidated Mean Log Value Across All Word Columns')
plt.xlabel('Category')
plt.ylabel('Consolidated Mean Log Value')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-21a9f6e58fea>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_cleaned.rename(columns={
# <ipython-input-5-21a9f6e58fea>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_cleaned.dropna(subset=['워드1', '워드2', '워드3', '워드4', '워드5', 'log'], inplace=True)
# <ipython-input-5-21a9f6e58fea>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_cleaned[col] = df_csv_cleaned[col].astype(str)
# <ipython-input-5-21a9f6e58fea>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_csv_cleaned['log'] = df_csv_cleaned['log'].astype(float)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 53080 (\N{HANGUL SYLLABLE KON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 55129 (\N{HANGUL SYLLABLE HEULG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 44264 (\N{HANGUL SYLLABLE GOL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-5-21a9f6e58fea>:54: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53080 (\N{HANGUL SYLLABLE KON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 55129 (\N{HANGUL SYLLABLE HEULG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46321 (\N{HANGUL SYLLABLE DEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44264 (\N{HANGUL SYLLABLE GOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.

# %% [markdown]
# 4. csv파일을 읽어온 후, 워드2~워드5까지의 요소 중 mean log value값 top8만 뽑아서 그래프 그리기

# %%
# CSV 파일을 읽어 DataFrame으로 변환 (불필요한 헤더 행은 생략)
df = pd.read_csv('./rawData/fire-over-5hecs.csv', skiprows=2)

# 관심 있는 컬럼과 'log' 컬럼만 추출
columns_of_interest = ['워드2', '워드3', '워드4', '워드5', 'log']
filtered_df = df[columns_of_interest]

# DataFrame을 'melt'하여 각 단어를 별개의 엔터티로 취급
melted_df = pd.melt(filtered_df, id_vars=['log'], value_vars=['워드2', '워드3', '워드4', '워드5'], value_name='Word')

# 각 단어별 평균 log 값을 계산
mean_log_values = melted_df.groupby('Word')['log'].mean().sort_values(ascending=False).reset_index()

# 상위 8개의 단어만 추출
top_8_elements = mean_log_values.head(8)

# 그래프 생성
plt.figure(figsize=(12, 8))
sns.barplot(x='Word', y='log', data=top_8_elements, palette='viridis')
plt.xlabel('Elements')
plt.ylabel('Mean Log Value')
plt.title('Top 8 Elements with the Highest Mean Log Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5. 최종선택 알고리즘=> 'random forest algorithm'
# 3번,4번 과정은 생략하고 실행해도 무방함.
#
#
#
# > **현재 설정값**
#
#
#
#
#
# *   트리의 갯수: 100개
# *   트리의 깊이: 제한 없음
#
# *   random state(랜덤 데이터 생성 난수): None

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
plt.rc("font", family = "NanumGothic")

# 데이터 불러오기
df = pd.read_csv('./rawData/fire-over-5ha.csv', skiprows=2)
# 모든 '워드' 컬럼을 하나로 합치기
all_words = pd.concat([df['워드2'], df['워드3'], df['워드4'], df['워드5']])

# One-Hot 인코딩
one_hot_df = pd.get_dummies(all_words)

# 타깃 변수 (log 값)도 동일하게 반복하여 맞추기
y = pd.concat([df['log']] * 4).reset_index(drop=True)

# 랜덤 포레스트 모델 학습
rf = RandomForestRegressor(n_estimators=100, random_state=None)
rf.fit(one_hot_df, y)

# 변수 중요도 추출
feature_importances = rf.feature_importances_

# 중요도를 데이터프레임으로 변환
importance_df = pd.DataFrame({
    'Feature': one_hot_df.columns,
    'Importance': feature_importances
})

# 중요도 내림차순으로 정렬
sorted_importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 상위 10개 중요도 시각화
plt.figure(figsize=(10, 6))
plt.barh(sorted_importance_df['Feature'][:10], sorted_importance_df['Importance'][:10])
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Top 10 Feature Importances from Random Forest')
plt.show()

# %% [markdown]
# *결정 트리 한 개 얻어서 살펴보기. (설정값:트리의 깊이=3, 랜덤 트리 생성)

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt
import pandas as pd
plt.rc("font", family = "NanumGothic")
# 데이터 불러오기 (경로는 실제 파일 위치에 맞게 변경 필요)
df = pd.read_csv('./rawData/fire-over-5ha.csv', skiprows=2)

# 모든 '워드' 컬럼을 하나로 합치기
all_words = pd.concat([df['워드2'], df['워드3'], df['워드4'], df['워드5']])
one_hot_df = pd.get_dummies(all_words)

# 타깃 변수 (log 값)도 동일하게 반복하여 맞추기
y = pd.concat([df['log']] * 4).reset_index(drop=True)

# Subset for demonstration
X_subset = one_hot_df[:500]
y_subset = y[:500]

# Initialize and fit the model
single_tree = DecisionTreeRegressor(max_depth=10, random_state=None)
single_tree.fit(X_subset, y_subset)

# Plot the tree
plt.figure(figsize=(20, 10))
plot_tree(single_tree, filled=True, feature_names=one_hot_df.columns, rounded=True, fontsize=12)
plt.title('Example of a Single Decision Tree')
plt.show()

# %% [markdown]
# *결정 트리 세 개 얻어서 살펴보기. (설정값:트리의 깊이=3, 랜덤 트리 생성)

# %%
# Initialize and fit the RandomForest model with 3 estimators (trees)
rf_model = RandomForestRegressor(n_estimators=3, max_depth=3, random_state=None)
rf_model.fit(one_hot_df, y)

# Create subplots to plot each tree
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Plot each decision tree
for i, estimator in enumerate(rf_model.estimators_):
    plt.subplot(1, 3, i+1)
    plot_tree(estimator, filled=True, feature_names=one_hot_df.columns, rounded=True, fontsize=12)
    plt.title(f'Decision Tree {i+1}')

plt.tight_layout()
plt.show()
